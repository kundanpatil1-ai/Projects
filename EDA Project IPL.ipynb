# %% [markdown]
# # EDA Project
# # Exploratory Data Analysis on IPl Dataset

# %%
# Description of Data:
# I got a dataset of IPl from kaggle.The dataset contain seasonwise Head to Head matches from season 2008 to 2016.
# The dataset has Team names which team win toss and decision regarding Bat or Field and the match results
# Then winner team of match and which is player of the match
# Venue of the match


# Objective:
# To check impact of ground on match result

# %%
# importing required libraries:
import pandas as pd
import numpy as np
import seaborn as sns


#Visulisation
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("matches.csv")
df.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df.dtypes
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
df.drop(['umpire1','umpire2','umpire3'],axis=1)
df.head(5)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
df=df.rename(columns={"team1" : "T1","team2" :"T2", "toss_winner":"toss_win","toss_decision":"toss_dec","Player_of_match":"plyr_of_mat"})
df.head(5)
# Out:
#    id  season        city        date                     T1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                             T2                     toss_win toss_dec  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore    field  normal
# 1              Kings XI Punjab          Chennai Super Kings      bat  normal
# 2             Delhi Daredevils             Rajasthan Royals      bat  normal
# 3  Royal Challengers Bangalore               Mumbai Indians      bat  normal
# 4        Kolkata Knight Riders              Deccan Chargers      bat  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.shape
# Out:
# (577, 18)
